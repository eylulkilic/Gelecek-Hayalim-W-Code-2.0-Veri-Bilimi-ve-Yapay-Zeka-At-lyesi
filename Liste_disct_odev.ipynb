# %% [markdown]
# ### Ödev 1
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
#
# 1. Aşağıdaki işlemleri indexing ve slicing kullanarak liste üzerinde uygulayın.
#
#    - "3" değerine ulaşmak için indexleme yapın.
#    - "Hi-Kod" değerine ulaşmak için indexleme yapın.
#    - 4.7 değerine ulaşmak için indexleme yapın.
#    - 9,"3",8.4,"Hi-Kod" değerlerine ulaşmak için slicing yapın.
#    - 8.4,"Hi-Kod","False",4.7 değerlerine ulaşmak için slicing yapın.

# %%
my_list=["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

my_list[0]
# Out:
# 'Python'

# %%
my_list[1]
# Out:
# True

# %%
my_list[2]
# Out:
# 9

# %%
my_list[3]
# Out:
# '3'

# %%
my_list[4]
# Out:
# 8.4

# %%
my_list[5]
# Out:
# 'Hi-Kod'

# %%
my_list[7]
# Out:
# 4.7

# %%
sonuc_1 = liste[2:6]
print(f"slicing_1: {sonuc_1}")

sonuc_2 = liste[4:6]
print(f"slicing_2: {sonuc_2}")
# Out:
# slicing_1: [9, '3', 8.4, 'Hi-Kod']
# slicing_2: [8.4, 'Hi-Kod']

# %%
my_list[6]
# Out:
# 'False'

# %% [markdown]
# ### Ödev 2
#
# Verilen listede bulunan string veri tipindeki öğeleri yeni_liste isimli listeye eklenir.
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# %%
my_list = ["Python", True, 9, "3", 8.4, "Hi-Kod", "False", 4.7]
my_list2 = []

for eleman in my_list:
    my_list2.append(eleman)

print(f"Eski Liste: {my_list}")
print(f"Yeni Liste: {my_list2}")
# Out:
# Eski Liste: ['Python', True, 9, '3', 8.4, 'Hi-Kod', 'False', 4.7]
# Yeni Liste: ['Python', True, 9, '3', 8.4, 'Hi-Kod', 'False', 4.7]

# %% [markdown]
# ### Ödev 3
#
# Enumerate methodunu araştırın ve aşağıdaki örneği enumerate methodu ile yapın.

# %%
meyveler = ["elma", "armut", "muz"]

for index, meyve in enumerate(meyveler):
    print("{}. indexte bulunan meyve: {}".format(index, meyve))
# Out:
# 0. indexte bulunan meyve: elma
# 1. indexte bulunan meyve: armut
# 2. indexte bulunan meyve: muz

# %% [markdown]
# ## Sozluk

# %% [markdown]
# 1. Bir sözlük oluşturulur ve bu sözlükte öğrencilerin isimleri ve Matematik, Fizik, Kimya notları tutulur. Kullanıcıdan isim ve ders ismi(Matematik, Fizik, Kimya) istenir ve bu bilgilere göre çıktı verilir.

# %% [markdown]
# 2. Sözlük üzerinde değerleri değiştirme, yeni değer ekleme, kullanıcıya ulaşmak istediği bilgileri sorma gibi uygulamalar yapın.

# %%
ogrenciler = {
    "Efe": {"Matematik": 85, "Fizik": 78, "Kimya": 92},
    "Eylül": {"Matematik": 90, "Fizik": 88, "Kimya": 75},
    "ceylin": {"Matematik": 70, "Fizik": 60, "Kimya": 80}
}

isim = input("Öğrenci adı girin: ")
ders = input("Hangi ders? (Matematik, Fizik, Kimya): ")

if isim in ogrenciler:
    if ders in ogrenciler[isim]:
        print(f"{isim} adlı öğrencinin {ders} notu: {ogrenciler[isim][ders]}")
    else:
        print("Bu ders bulunamadı!")
else:
    print("Bu isimde bir öğrenci bulunamadı!")
# Out:
# Öğrenci adı girin:  Eylül
# Hangi ders? (Matematik, Fizik, Kimya):  Matematik
# Eylül adlı öğrencinin Matematik notu: 90
